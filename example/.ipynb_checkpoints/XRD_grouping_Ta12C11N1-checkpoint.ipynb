# %%
import pandas as pd
import numpy as np

# %%
### load dataframe 'xrd_scaled.py' ###
xrd = pd.read_csv('xrd_scaled.csv')

# user defined minimized xrd cutoff = x
xrd = xrd[xrd['minimized_diff'] <= 0.4]
xrd = xrd.reset_index(drop=True)

# exchange 'str_fixed' and 'str_scaled'
xrd_new = pd.DataFrame()
xrd_new['str_fixed'] = xrd['str_scaled']
xrd_new['str_scaled'] = xrd['str_fixed']
xrd_new['minimized_diff']  = xrd['minimized_diff']
del xrd['scaling_factor']

# append original xrd_scaled with new xrd_scaled
xrd = xrd.append(xrd_new).reset_index(drop=True)

# %%
### define a function taking two structures as arguments and returning 'True' if they satisfy xrd cutoff <= 0.4 ###
def xrd_group(key1,key2):
           df_key1 = xrd[xrd.str_fixed == key1]
           if key2 in df_key1.str_scaled.unique():
               return True

# %%
### load dataframe 'data_relaxed.csv' to make a list of all structure IDs ###
nrg = pd.read_csv('data_relaxed.csv')
nrg = nrg.sort_values('energy').reset_index(drop=True)
nrg['E_Emin_fu'] = 2*nrg['E-Emin']

# make a list of 'structure IDs' from 'nrg'
ordered_en = nrg['str_id'].to_list()

# %%
xrd.head()
# Out:
#                 str_fixed               str_scaled  minimized_diff
# 0  POSCAR_24_atoms_24_117  POSCAR_24_atoms_24_1093        0.027619
# 1  POSCAR_24_atoms_24_117   POSCAR_24_atoms_24_952        0.020004
# 2  POSCAR_24_atoms_24_117   POSCAR_24_atoms_24_295        0.028406
# 3  POSCAR_24_atoms_24_117   POSCAR_24_atoms_24_455        0.021869
# 4  POSCAR_24_atoms_24_117   POSCAR_24_atoms_24_646        0.022094

# %%
nrg.head()
# Out:
#                     str_id  numatom    energy  finalspacegroup    E-Emin  \
# 0   POSCAR_24_atoms_24_117       24 -9.763901               10  0.000000
# 1  POSCAR_24_atoms_24_1093       24 -9.762439               10  0.001462
# 2   POSCAR_24_atoms_24_952       24 -9.758300               10  0.005601
# 3   POSCAR_24_atoms_24_295       24 -9.755809               12  0.008092
# 4   POSCAR_24_atoms_24_455       24 -9.755476                2  0.008425
#
#    E_form_fu  E_Emin_fu
# 0   0.009031   0.000000
# 1   0.011955   0.002923
# 2   0.020233   0.011201
# 3   0.025216   0.016185
# 4   0.025882   0.016851

# %%
############################ Grouping Step 1 ###############################################

### for loop to make groups based on xrd ###
equals = []

for name in ordered_en:

     print(name)

     if len(equals)==0:
         equals.append([name])

     else:
         is_in=False
         for ii in range(len(equals)):
             if xrd_group(name,equals[ii][0]):
                 equals[ii].append(name)
                 is_in=True
                 break

         if not is_in:
             equals.append([name])


# store groups (equals list) in a datframe
df = pd.DataFrame()
df['groups'] = equals
# Out:
# POSCAR_24_atoms_24_117
# POSCAR_24_atoms_24_1093
# POSCAR_24_atoms_24_952
# POSCAR_24_atoms_24_295
# POSCAR_24_atoms_24_455
# POSCAR_24_atoms_24_646
# POSCAR_24_atoms_24_864
# POSCAR_24_atoms_24_41
# POSCAR_24_atoms_24_737
# POSCAR_24_atoms_24_1071
# POSCAR_24_atoms_24_245
# POSCAR_24_atoms_24_609
             xrd_key = xrd[xrd.str_fixed == df.groups[i][j]]
             for k in range(i+1,len(df)):
                 for kk in range(len(df.groups[k])):
                     if df.groups[k][kk] in xrd_key.str_scaled.unique():
                         print("similar groups found with indices {} and {}".format(i,j))
                         index1.append(i)
                         index2.append(k)

    if len(index1) == 0:
        break

    #store indices in a dataframe
    df_index = pd.DataFrame()
    df_index['indx1'] = index1
    df_index['indx2'] = index2

    # keep only unique 'indx1' and 'indx2' pairs
    df_index = df_index.drop_duplicates().reset_index(drop=True)
    df_index = df_index.sort_values('indx1',ascending=False).reset_index(drop=True)

    # merge groups of indices 'indx2' with groups of indices 'indx1' in 'df'
    # only keep unique structures after merging
    for s in range(len(df_index)):
         df.groups[df_index.indx1[s]] = np.unique(np.append(df.groups[df_index.indx1[s]],df.groups[df_index.indx2[s]]))

    # drop groups in 'df' of indices 'indx2' using df_index
    df = df.drop(df.index[df_index['indx2'].unique().tolist()]).reset_index(drop=True)

print("Grouping complete")
# Out:
# similar groups found with indices 0 and 1
# similar groups found with indices 0 and 1
# similar groups found with indices 0 and 1
# similar groups found with indices 0 and 26
# similar groups found with indices 0 and 26
# similar groups found with indices 0 and 26
# similar groups found with indices 0 and 27
# similar groups found with indices 0 and 27
# similar groups found with indices 0 and 27
# similar groups found with indices 0 and 28
# similar groups found with indices 0 and 28
# similar groups found with indices 0 and 28
# similar groups found with indices 0 and 35
# similar groups found with indices 0 and 35
# similar groups found with indices 0 and 41
# similar groups found with indices 0 and 41
# similar groups found with indices 0 and 41
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 42
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 43
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 44
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 45
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 46
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 47
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 48
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 49
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 50
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 51
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 52
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 53
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 54
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 55
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 56
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 57
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 58
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 59
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 60
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 61
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 62
# similar groups found with indices 0 and 63
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 64
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 65
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 66
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 67
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 68
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 69
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 70
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 71
# similar groups found with indices 0 and 72
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 73
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 74
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 75
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 0 and 76
# similar groups found with indices 2 and 11
# similar groups found with indices 2 and 13
# similar groups found with indices 2 and 14
# similar groups found with indices 3 and 1
# similar groups found with indices 3 and 1
# similar groups found with indices 3 and 1
# similar groups found with indices 3 and 2
# similar groups found with indices 3 and 2
# similar groups found with indices 3 and 2
# similar groups found with indices 3 and 3
# similar groups found with indices 3 and 3
# similar groups found with indices 3 and 3
# similar groups found with indices 3 and 3
# similar groups found with indices 3 and 4
# similar groups found with indices 3 and 4
# similar groups found with indices 3 and 4
# similar groups found with indices 3 and 4
# similar groups found with indices 3 and 5
# similar groups found with indices 3 and 6
# similar groups found with indices 3 and 6
# similar groups found with indices 3 and 6
# similar groups found with indices 3 and 6
# similar groups found with indices 5 and 3
# similar groups found with indices 5 and 3
# similar groups found with indices 5 and 3
# similar groups found with indices 5 and 4
# similar groups found with indices 5 and 4
# similar groups found with indices 5 and 4
# similar groups found with indices 5 and 5
# similar groups found with indices 5 and 5
# similar groups found with indices 5 and 5
# similar groups found with indices 5 and 6
# similar groups found with indices 5 and 6
# similar groups found with indices 5 and 6
# similar groups found with indices 5 and 7
# similar groups found with indices 5 and 7
# similar groups found with indices 5 and 8
# similar groups found with indices 5 and 8
# similar groups found with indices 5 and 8
# similar groups found with indices 6 and 1
# similar groups found with indices 7 and 1
# similar groups found with indices 7 and 2
# similar groups found with indices 7 and 3
# similar groups found with indices 7 and 3
# similar groups found with indices 7 and 4
# similar groups found with indices 7 and 5
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 7
# similar groups found with indices 7 and 8
# similar groups found with indices 7 and 8
# similar groups found with indices 7 and 8
# similar groups found with indices 7 and 8
# similar groups found with indices 7 and 8
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 11
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 12
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 13
# similar groups found with indices 7 and 14
# similar groups found with indices 7 and 14
# similar groups found with indices 7 and 15
# similar groups found with indices 7 and 17
# similar groups found with indices 7 and 17
# similar groups found with indices 7 and 17
# similar groups found with indices 7 and 18
# similar groups found with indices 7 and 18
# similar groups found with indices 7 and 19
# similar groups found with indices 7 and 21
# similar groups found with indices 7 and 21
# similar groups found with indices 7 and 22
# similar groups found with indices 7 and 22
# similar groups found with indices 7 and 23
# similar groups found with indices 7 and 24
# similar groups found with indices 7 and 26
# similar groups found with indices 8 and 1
# similar groups found with indices 9 and 1
# similar groups found with indices 9 and 1
# similar groups found with indices 12 and 3
# similar groups found with indices 12 and 3
# similar groups found with indices 12 and 5
# similar groups found with indices 12 and 9
# similar groups found with indices 12 and 9
# similar groups found with indices 12 and 13
# similar groups found with indices 12 and 13
# similar groups found with indices 12 and 13
# similar groups found with indices 12 and 14
# similar groups found with indices 12 and 14
# similar groups found with indices 12 and 14
# similar groups found with indices 20 and 1
# similar groups found with indices 20 and 1
# similar groups found with indices 22 and 1
# similar groups found with indices 34 and 1
# similar groups found with indices 45 and 1
# similar groups found with indices 61 and 3
# similar groups found with indices 88 and 1
# similar groups found with indices 121 and 1
# similar groups found with indices 126 and 1
# similar groups found with indices 126 and 1
# similar groups found with indices 126 and 1
# similar groups found with indices 130 and 1
# similar groups found with indices 130 and 1
# similar groups found with indices 130 and 1
# similar groups found with indices 130 and 1
# similar groups found with indices 130 and 1
# similar groups found with indices 130 and 2
# similar groups found with indices 130 and 2
# similar groups found with indices 134 and 1
# similar groups found with indices 134 and 1
# similar groups found with indices 149 and 1
# similar groups found with indices 164 and 1
# similar groups found with indices 164 and 1
# similar groups found with indices 164 and 1
# similar groups found with indices 164 and 1
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 2
# similar groups found with indices 164 and 3
# similar groups found with indices 164 and 4
# similar groups found with indices 164 and 4
# similar groups found with indices 164 and 4
# similar groups found with indices 164 and 5
# similar groups found with indices 164 and 5
# similar groups found with indices 165 and 1
# similar groups found with indices 165 and 1
# similar groups found with indices 165 and 2
# similar groups found with indices 165 and 2
# similar groups found with indices 165 and 2
# similar groups found with indices 165 and 2
# similar groups found with indices 165 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 2
# similar groups found with indices 175 and 3
# similar groups found with indices 175 and 3
# similar groups found with indices 175 and 4
# similar groups found with indices 175 and 4
# similar groups found with indices 175 and 5
# similar groups found with indices 175 and 6
# similar groups found with indices 175 and 6
# similar groups found with indices 175 and 6
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 1
# similar groups found with indices 182 and 2
# similar groups found with indices 182 and 2
# similar groups found with indices 186 and 1
# similar groups found with indices 186 and 2
# similar groups found with indices 186 and 2
# similar groups found with indices 203 and 2
# similar groups found with indices 203 and 2
# similar groups found with indices 213 and 1
# similar groups found with indices 222 and 1
# similar groups found with indices 222 and 2
# similar groups found with indices 222 and 2
# similar groups found with indices 222 and 2
# similar groups found with indices 222 and 3
# similar groups found with indices 222 and 3
# similar groups found with indices 222 and 3
# similar groups found with indices 223 and 1
# similar groups found with indices 228 and 1
# similar groups found with indices 228 and 1
# similar groups found with indices 228 and 1
# similar groups found with indices 228 and 1
# similar groups found with indices 228 and 1
# similar groups found with indices 233 and 1
# similar groups found with indices 233 and 1
# similar groups found with indices 233 and 2
# similar groups found with indices 256 and 1
# similar groups found with indices 256 and 1
# similar groups found with indices 256 and 1
# similar groups found with indices 256 and 4
# similar groups found with indices 261 and 1
# similar groups found with indices 261 and 1
# similar groups found with indices 261 and 1
# similar groups found with indices 261 and 2
# similar groups found with indices 261 and 2
# similar groups found with indices 261 and 3
# similar groups found with indices 261 and 3
# similar groups found with indices 261 and 3
# similar groups found with indices 261 and 4
# similar groups found with indices 261 and 4
# similar groups found with indices 261 and 4
# similar groups found with indices 261 and 4
# similar groups found with indices 261 and 4
# similar groups found with indices 261 and 4
# similar groups found with indices 267 and 1
# similar groups found with indices 274 and 1
# similar groups found with indices 274 and 1
# similar groups found with indices 292 and 1
# similar groups found with indices 292 and 1
# similar groups found with indices 293 and 2
# similar groups found with indices 293 and 2
# similar groups found with indices 315 and 1
# similar groups found with indices 315 and 1
# similar groups found with indices 315 and 1
# similar groups found with indices 315 and 1
# similar groups found with indices 318 and 1
# similar groups found with indices 318 and 1
# similar groups found with indices 320 and 3
# similar groups found with indices 324 and 1
# similar groups found with indices 330 and 1
# similar groups found with indices 330 and 1
# similar groups found with indices 330 and 1
# similar groups found with indices 330 and 1
# similar groups found with indices 332 and 1
# similar groups found with indices 332 and 1
# similar groups found with indices 347 and 1
# similar groups found with indices 356 and 1
# similar groups found with indices 356 and 2
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 3
# similar groups found with indices 356 and 4
# similar groups found with indices 356 and 5
# similar groups found with indices 356 and 5
# similar groups found with indices 356 and 5
# similar groups found with indices 357 and 1
# similar groups found with indices 357 and 1
# similar groups found with indices 357 and 1
# similar groups found with indices 360 and 2
# similar groups found with indices 360 and 2
# similar groups found with indices 360 and 2
# similar groups found with indices 360 and 2
# similar groups found with indices 360 and 2
# similar groups found with indices 360 and 3
# similar groups found with indices 360 and 3
# similar groups found with indices 374 and 1
# similar groups found with indices 374 and 1
# similar groups found with indices 374 and 4
# similar groups found with indices 374 and 4
# similar groups found with indices 374 and 5
# similar groups found with indices 374 and 5
# similar groups found with indices 374 and 5
# similar groups found with indices 376 and 1
# similar groups found with indices 401 and 1
# similar groups found with indices 405 and 1
# similar groups found with indices 417 and 1
# similar groups found with indices 417 and 1
# similar groups found with indices 417 and 1
# similar groups found with indices 417 and 1
# similar groups found with indices 419 and 1
# similar groups found with indices 419 and 2
# similar groups found with indices 420 and 1
# similar groups found with indices 420 and 1
# similar groups found with indices 420 and 2
# similar groups found with indices 420 and 2
# similar groups found with indices 453 and 1
# similar groups found with indices 453 and 1
# similar groups found with indices 458 and 1
# similar groups found with indices 458 and 2
# similar groups found with indices 458 and 2
# similar groups found with indices 460 and 1
# similar groups found with indices 462 and 1
# similar groups found with indices 483 and 1
# similar groups found with indices 483 and 1
# similar groups found with indices 493 and 1
# similar groups found with indices 495 and 1
# similar groups found with indices 495 and 1
# similar groups found with indices 506 and 1
# similar groups found with indices 506 and 1
# similar groups found with indices 516 and 1
# similar groups found with indices 537 and 1
# similar groups found with indices 538 and 1
# similar groups found with indices 544 and 1
# similar groups found with indices 569 and 1
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 2
# similar groups found with indices 71 and 2
# similar groups found with indices 71 and 2
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 4
# similar groups found with indices 71 and 5
# similar groups found with indices 71 and 5
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 9
# similar groups found with indices 71 and 9
# ...
# similar groups found with indices 195 and 37
# similar groups found with indices 195 and 40
# similar groups found with indices 195 and 40
# similar groups found with indices 195 and 41
# similar groups found with indices 195 and 41
# similar groups found with indices 195 and 43
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 44
# similar groups found with indices 195 and 45
# similar groups found with indices 195 and 45
# similar groups found with indices 238 and 0
# similar groups found with indices 238 and 1
# similar groups found with indices 238 and 1
# similar groups found with indices 238 and 5
# similar groups found with indices 238 and 5
# similar groups found with indices 238 and 8
# similar groups found with indices 238 and 9
# similar groups found with indices 238 and 9
# similar groups found with indices 238 and 9
# similar groups found with indices 238 and 9
# similar groups found with indices 238 and 9
# similar groups found with indices 238 and 10
# similar groups found with indices 238 and 11
# similar groups found with indices 238 and 12
# similar groups found with indices 253 and 0
# similar groups found with indices 253 and 0
# similar groups found with indices 253 and 3
# similar groups found with indices 253 and 4
# similar groups found with indices 253 and 5
# similar groups found with indices 253 and 5
# similar groups found with indices 253 and 5
# similar groups found with indices 253 and 5
# similar groups found with indices 253 and 7
# similar groups found with indices 253 and 8
# similar groups found with indices 253 and 10
# similar groups found with indices 253 and 10
# similar groups found with indices 253 and 12
# similar groups found with indices 253 and 12
# similar groups found with indices 253 and 12
# similar groups found with indices 253 and 12
# similar groups found with indices 253 and 12
# similar groups found with indices 253 and 13
# similar groups found with indices 253 and 14
# similar groups found with indices 253 and 14
# similar groups found with indices 253 and 14
# similar groups found with indices 253 and 15
# similar groups found with indices 253 and 15
# similar groups found with indices 253 and 15
# similar groups found with indices 253 and 17
# similar groups found with indices 253 and 19
# similar groups found with indices 253 and 20
# similar groups found with indices 253 and 20
# similar groups found with indices 253 and 22
# similar groups found with indices 253 and 23
# similar groups found with indices 253 and 23
# similar groups found with indices 253 and 23
# similar groups found with indices 253 and 23
# similar groups found with indices 253 and 24
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 0
# similar groups found with indices 71 and 1
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 3
# similar groups found with indices 71 and 6
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 7
# similar groups found with indices 71 and 8
# similar groups found with indices 71 and 9
# similar groups found with indices 71 and 10
# similar groups found with indices 71 and 10
# similar groups found with indices 71 and 11
# similar groups found with indices 71 and 12
# similar groups found with indices 71 and 12
# similar groups found with indices 71 and 13
# similar groups found with indices 71 and 14
# similar groups found with indices 71 and 14
# similar groups found with indices 71 and 16
# similar groups found with indices 71 and 16
# similar groups found with indices 71 and 17
# similar groups found with indices 71 and 19
# similar groups found with indices 71 and 21
# similar groups found with indices 71 and 21
# similar groups found with indices 71 and 22
# similar groups found with indices 71 and 22
# similar groups found with indices 71 and 22
# similar groups found with indices 71 and 23
# similar groups found with indices 71 and 27
# similar groups found with indices 71 and 30
# similar groups found with indices 71 and 30
# similar groups found with indices 71 and 31
# similar groups found with indices 71 and 32
# similar groups found with indices 71 and 32
# similar groups found with indices 71 and 32
# similar groups found with indices 71 and 33
# similar groups found with indices 71 and 33
# similar groups found with indices 71 and 34
# similar groups found with indices 71 and 34
# similar groups found with indices 71 and 36
# similar groups found with indices 71 and 36
# similar groups found with indices 71 and 36
# similar groups found with indices 71 and 37
# similar groups found with indices 71 and 38
# similar groups found with indices 71 and 40
# similar groups found with indices 71 and 40
# similar groups found with indices 71 and 40
# similar groups found with indices 71 and 42
# similar groups found with indices 71 and 42
# similar groups found with indices 71 and 42
# similar groups found with indices 71 and 43
# similar groups found with indices 71 and 43
# similar groups found with indices 71 and 43
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 44
# similar groups found with indices 71 and 47
# similar groups found with indices 71 and 50
# similar groups found with indices 71 and 51
# similar groups found with indices 71 and 51
# similar groups found with indices 71 and 52
# similar groups found with indices 71 and 52
# similar groups found with indices 71 and 52
# similar groups found with indices 71 and 52
# similar groups found with indices 71 and 52
# similar groups found with indices 71 and 54
# similar groups found with indices 71 and 55
# similar groups found with indices 71 and 55
# similar groups found with indices 71 and 55
# similar groups found with indices 71 and 57
# similar groups found with indices 71 and 57
# similar groups found with indices 71 and 57
# similar groups found with indices 71 and 57
# similar groups found with indices 71 and 58
# similar groups found with indices 71 and 58
# similar groups found with indices 71 and 59
# similar groups found with indices 71 and 59
# similar groups found with indices 71 and 60
# similar groups found with indices 71 and 64
# similar groups found with indices 71 and 64
# similar groups found with indices 71 and 65
# similar groups found with indices 71 and 66
# similar groups found with indices 71 and 66
# similar groups found with indices 71 and 67
# similar groups found with indices 71 and 70
# similar groups found with indices 71 and 70
# similar groups found with indices 71 and 72
# similar groups found with indices 71 and 74
# similar groups found with indices 71 and 75
# similar groups found with indices 71 and 78
# similar groups found with indices 71 and 78
# similar groups found with indices 71 and 78
# similar groups found with indices 71 and 78
# similar groups found with indices 71 and 79
# similar groups found with indices 71 and 79
# similar groups found with indices 71 and 81
# similar groups found with indices 71 and 82
# similar groups found with indices 71 and 83
# similar groups found with indices 71 and 83
# similar groups found with indices 71 and 83
# similar groups found with indices 71 and 83
# similar groups found with indices 71 and 85
# similar groups found with indices 71 and 85
# similar groups found with indices 71 and 85
# similar groups found with indices 71 and 87
# similar groups found with indices 71 and 87
# similar groups found with indices 71 and 87
# similar groups found with indices 71 and 87
# similar groups found with indices 71 and 87
# similar groups found with indices 71 and 88
# similar groups found with indices 71 and 89
# similar groups found with indices 71 and 91
# similar groups found with indices 71 and 93
# similar groups found with indices 71 and 95
# similar groups found with indices 71 and 95
# similar groups found with indices 71 and 95
# similar groups found with indices 71 and 95
# similar groups found with indices 71 and 97
# similar groups found with indices 71 and 98
# similar groups found with indices 71 and 98
# similar groups found with indices 71 and 103
# similar groups found with indices 71 and 107
# similar groups found with indices 71 and 107
# similar groups found with indices 71 and 108
# similar groups found with indices 71 and 108
# similar groups found with indices 71 and 109
# similar groups found with indices 71 and 109
# similar groups found with indices 71 and 110
# similar groups found with indices 71 and 110
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 119
# similar groups found with indices 71 and 125
# similar groups found with indices 71 and 125
# similar groups found with indices 71 and 125
# similar groups found with indices 71 and 127
# similar groups found with indices 71 and 130
# similar groups found with indices 71 and 131
# similar groups found with indices 71 and 133
# similar groups found with indices 71 and 133
# similar groups found with indices 71 and 135
# similar groups found with indices 71 and 137
# similar groups found with indices 71 and 137
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 138
# similar groups found with indices 71 and 142
# similar groups found with indices 71 and 142
# similar groups found with indices 71 and 142
# similar groups found with indices 71 and 143
# similar groups found with indices 71 and 144
# similar groups found with indices 71 and 144
# similar groups found with indices 71 and 144
# similar groups found with indices 71 and 145
# similar groups found with indices 71 and 145
# similar groups found with indices 71 and 146
# similar groups found with indices 71 and 147
# similar groups found with indices 71 and 147
# similar groups found with indices 71 and 149
# similar groups found with indices 71 and 149
# similar groups found with indices 71 and 149
# similar groups found with indices 71 and 150
# similar groups found with indices 71 and 150
# similar groups found with indices 71 and 153
# similar groups found with indices 71 and 153
# similar groups found with indices 71 and 153
# similar groups found with indices 71 and 156
# similar groups found with indices 71 and 156
# similar groups found with indices 71 and 156
# similar groups found with indices 71 and 156
# similar groups found with indices 71 and 156
# similar groups found with indices 71 and 159
# similar groups found with indices 71 and 160
# similar groups found with indices 71 and 160
# similar groups found with indices 71 and 160
# similar groups found with indices 71 and 161
# similar groups found with indices 71 and 165
# similar groups found with indices 71 and 167
# similar groups found with indices 71 and 167
# similar groups found with indices 71 and 167
# similar groups found with indices 71 and 168
# similar groups found with indices 71 and 170
# similar groups found with indices 71 and 170
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 171
# similar groups found with indices 71 and 172
# similar groups found with indices 71 and 173
# similar groups found with indices 71 and 174
# similar groups found with indices 71 and 177
# similar groups found with indices 71 and 178
# similar groups found with indices 71 and 179
# similar groups found with indices 71 and 180
# similar groups found with indices 71 and 180
# similar groups found with indices 71 and 181
# similar groups found with indices 71 and 182
# similar groups found with indices 71 and 183
# similar groups found with indices 71 and 183
# similar groups found with indices 71 and 183
# similar groups found with indices 71 and 185
# similar groups found with indices 71 and 185
# similar groups found with indices 71 and 186
# similar groups found with indices 71 and 186
# similar groups found with indices 71 and 187
# similar groups found with indices 71 and 187
# similar groups found with indices 71 and 188
# similar groups found with indices 71 and 188
# similar groups found with indices 71 and 188
# similar groups found with indices 71 and 188
# similar groups found with indices 71 and 189
# similar groups found with indices 71 and 189
# similar groups found with indices 71 and 192
# similar groups found with indices 71 and 194
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 196
# similar groups found with indices 71 and 197
# similar groups found with indices 71 and 197
# similar groups found with indices 71 and 197
# similar groups found with indices 71 and 197
# similar groups found with indices 71 and 199
# similar groups found with indices 71 and 199
# similar groups found with indices 71 and 199
# similar groups found with indices 71 and 199
# similar groups found with indices 71 and 199
# similar groups found with indices 71 and 200
# similar groups found with indices 71 and 201
# similar groups found with indices 71 and 201
# similar groups found with indices 71 and 201
# similar groups found with indices 71 and 201
# similar groups found with indices 71 and 201
# similar groups found with indices 71 and 202
# similar groups found with indices 71 and 203
# similar groups found with indices 71 and 204
# similar groups found with indices 71 and 204
# similar groups found with indices 71 and 204
# similar groups found with indices 71 and 205
# similar groups found with indices 71 and 206
# similar groups found with indices 71 and 206
# similar groups found with indices 71 and 206
# similar groups found with indices 71 and 206
# similar groups found with indices 71 and 207
# similar groups found with indices 71 and 207
# similar groups found with indices 71 and 209
# similar groups found with indices 71 and 209
# similar groups found with indices 71 and 210
# similar groups found with indices 71 and 210
# similar groups found with indices 71 and 210
# similar groups found with indices 71 and 211
# similar groups found with indices 71 and 211
# similar groups found with indices 71 and 212
# similar groups found with indices 71 and 212
# similar groups found with indices 71 and 212
# similar groups found with indices 71 and 212
# similar groups found with indices 71 and 212
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 213
# similar groups found with indices 71 and 214
# similar groups found with indices 71 and 217
# similar groups found with indices 71 and 217
# similar groups found with indices 71 and 217
# similar groups found with indices 71 and 219
# similar groups found with indices 71 and 219
# similar groups found with indices 71 and 219
# similar groups found with indices 71 and 219
# similar groups found with indices 71 and 220
# similar groups found with indices 71 and 220
# similar groups found with indices 71 and 221
# similar groups found with indices 71 and 221
# Grouping complete

# %%
df.head()
# Out:
#                                               groups
# 0  [POSCAR_24_atoms_24_1003, POSCAR_24_atoms_24_1...
# 1  [POSCAR_24_atoms_24_1001, POSCAR_24_atoms_24_4...
# 2  [POSCAR_24_atoms_24_110, POSCAR_24_atoms_24_11...
# 3  [POSCAR_24_atoms_24_1011, POSCAR_24_atoms_24_1...
# 4  [POSCAR_24_atoms_24_999, POSCAR_24_atoms_24_84...
